# %% [markdown]
# <a href="https://colab.research.google.com/github/nnknishant/nnknishant/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import files


uploaded = files.upload()
# Out:
#      <input type="file" id="files-0745a264-5101-4632-b2be-b6d24c776906" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0745a264-5101-4632-b2be-b6d24c776906">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("online_store_customer_data.csv")

# %%
df
# Out:
#      Transaction_date  Transaction_ID  Gender   Age Marital_status  \
# 0            1/1/2019          151200  Female  19.0         Single
# 1            1/1/2019          151201    Male  49.0         Single
# 2            1/1/2019          151202    Male  63.0        Married
# 3            1/1/2019          151203     NaN  18.0         Single
# 4            1/1/2019          151204    Male  27.0         Single
# ...               ...             ...     ...   ...            ...
# 2507         5/1/2021          153695  Female  57.0         Single
# 2508         5/1/2021          153696  Female  36.0        Married
# 2509         5/1/2021          153697    Male  22.0         Single
# 2510         5/1/2021          153698     NaN  44.0         Single
# 2511         5/1/2021          153699    Male  48.0         Single
#
#          State_names   Segment Employees_status Payment_method  Referal  \
# 0             Kansas     Basic     Unemployment          Other      1.0
# ...

# %%
df.head()
# Out:
#   Transaction_date  Transaction_ID  Gender   Age Marital_status  State_names  \
# 0         1/1/2019          151200  Female  19.0         Single       Kansas
# 1         1/1/2019          151201    Male  49.0         Single     Illinois
# 2         1/1/2019          151202    Male  63.0        Married   New Mexico
# 3         1/1/2019          151203     NaN  18.0         Single     Virginia
# 4         1/1/2019          151204    Male  27.0         Single  Connecticut
#
#     Segment Employees_status Payment_method  Referal  Amount_spent
# 0     Basic     Unemployment          Other      1.0       2051.36
# 1     Basic    self-employed           Card      0.0        544.04
# 2     Basic          workers         PayPal      1.0       1572.60
# 3  Platinum          workers           Card      1.0       1199.79
# 4     Basic    self-employed           Card      0.0           NaN

# %%
df.tail()
# Out:
#      Transaction_date  Transaction_ID  Gender   Age Marital_status  \
# 2507         5/1/2021          153695  Female  57.0         Single
# 2508         5/1/2021          153696  Female  36.0        Married
# 2509         5/1/2021          153697    Male  22.0         Single
# 2510         5/1/2021          153698     NaN  44.0         Single
# 2511         5/1/2021          153699    Male  48.0         Single
#
#          State_names   Segment Employees_status Payment_method  Referal  \
# 2507  South Carolina  Platinum    self-employed           Card      0.0
# 2508          Hawaii    Silver    self-employed         PayPal      1.0
# 2509  South Carolina     Basic          workers         PayPal      1.0
# 2510        New York     Basic        Employees         PayPal      0.0
# 2511      California    Silver          workers         PayPal      1.0
#
#       Amount_spent
# 2507        150.10
# 2508        708.88
# 2509       2030.07
# 2510       1909.77
# 2511       1073.15

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2512 entries, 0 to 2511
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction_date  2512 non-null   object
#  1   Transaction_ID    2512 non-null   int64
#  2   Gender            2484 non-null   object
#  3   Age               2470 non-null   float64
#  4   Marital_status    2512 non-null   object
#  5   State_names       2512 non-null   object
#  6   Segment           2512 non-null   object
#  7   Employees_status  2486 non-null   object
#  8   Payment_method    2512 non-null   object
#  9   Referal           2357 non-null   float64
#  10  Amount_spent      2270 non-null   float64
# dtypes: float64(3), int64(1), object(7)
# memory usage: 216.0+ KB

# %%
df.index
# Out:
# RangeIndex(start=0, stop=2512, step=1)

# %%
df.columns
# Out:
# Index(['Transaction_date', 'Transaction_ID', 'Gender', 'Age', 'Marital_status',
#        'State_names', 'Segment', 'Employees_status', 'Payment_method',
#        'Referal', 'Amount_spent'],
#       dtype='object')

# %%
df.shape
# Out:
# (2512, 11)

# %%
df.size
# Out:
# 27632

# %%
 df.dtypes
# Out:
# Transaction_date     object
# Transaction_ID        int64
# Gender               object
# Age                 float64
# Marital_status       object
# State_names          object
# Segment              object
# Employees_status     object
# Payment_method       object
# Referal             float64
# Amount_spent        float64
# dtype: object

# %%
df[df.duplicated()]
# Out:
#     Transaction_date  Transaction_ID  Gender   Age Marital_status  \
# 64         1/25/2019          151259    Male  73.0        Married
# 65         1/26/2019          151260    Male  55.0        Married
# 66         1/26/2019          151261  Female  72.0        Married
# 67         1/26/2019          151262    Male  15.0        Married
# 68         1/27/2019          151263  Female  63.0         Single
# 109         2/6/2019          151297    Male  60.0        Married
# 110         2/7/2019          151298  Female  45.0        Married
# 111         2/8/2019          151299    Male  33.0         Single
# 112         2/8/2019          151300    Male  24.0        Married
# 113         2/8/2019          151301  Female  53.0         Single
# 114         2/8/2019          151302  Female  70.0        Married
# 115         2/8/2019          151303    Male  16.0        Married
#
#         State_names   Segment Employees_status Payment_method  Referal  \
# ...

# %%
df.drop_duplicates(inplace = True)

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Transaction_date, Transaction_ID, Gender, Age, Marital_status, State_names, Segment, Employees_status, Payment_method, Referal, Amount_spent]
# Index: []

# %%
df.shape
# Out:
# (2500, 11)

# %%
df.isnull()
# Out:
#       Transaction_date  Transaction_ID  Gender    Age  Marital_status  \
# 0                False           False   False  False           False
# 1                False           False   False  False           False
# 2                False           False   False  False           False
# 3                False           False    True  False           False
# 4                False           False   False  False           False
# ...                ...             ...     ...    ...             ...
# 2507             False           False   False  False           False
# 2508             False           False   False  False           False
# 2509             False           False   False  False           False
# 2510             False           False    True  False           False
# 2511             False           False   False  False           False
#
#       State_names  Segment  Employees_status  Payment_method  Referal  \
# ...

# %%
df.isnull().sum()
# Out:
# Transaction_date      0
# Transaction_ID        0
# Gender               28
# Age                  42
# Marital_status        0
# State_names           0
# Segment               0
# Employees_status     26
# Payment_method        0
# Referal             154
# Amount_spent        241
# dtype: int64

# %%
import seaborn as sns

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df['Gender']
# Out:
# 0       Female
# 1         Male
# 2         Male
# 3          NaN
# 4         Male
#          ...
# 2507    Female
# 2508    Female
# 2509      Male
# 2510       NaN
# 2511      Male
# Name: Gender, Length: 2500, dtype: object

# %%
df[df['State_names'].isin(['West Virginia'])]
# Out:
#      Transaction_date  Transaction_ID  Gender   Age Marital_status  \
# 59          1/25/2019          151259    Male  73.0        Married
# 143         2/20/2019          151331    Male  28.0         Single
# 157         2/26/2019          151345    Male  25.0        Married
# 175          3/5/2019          151363  Female  17.0         Single
# 187          3/9/2019          151375  Female  47.0        Married
# 240         3/26/2019          151428  Female  59.0         Single
# 258          4/1/2019          151446    Male  54.0         Single
# 358         4/30/2019          151546  Female  56.0         Single
# 412         5/16/2019          151600    Male  30.0        Married
# 478          6/5/2019          151666    Male  71.0         Single
# 519         6/19/2019          151707  Female  69.0        Married
# 525         6/21/2019          151713    Male  55.0        Married
# 526         6/21/2019          151714  Female  65.0         Single
# ...

# %%
df[df['Payment_method'].isin(['PayPal'])]
# Out:
#      Transaction_date  Transaction_ID  Gender   Age Marital_status  \
# 2            1/1/2019          151202    Male  63.0        Married
# 5            1/3/2019          151205    Male  71.0         Single
# 6            1/3/2019          151206  Female  34.0        Married
# 7            1/3/2019          151207    Male  37.0        Married
# 10           1/4/2019          151210  Female  56.0        Married
# ...               ...             ...     ...   ...            ...
# 2503        4/29/2021          153691    Male  67.0         Single
# 2508         5/1/2021          153696  Female  36.0        Married
# 2509         5/1/2021          153697    Male  22.0         Single
# 2510         5/1/2021          153698     NaN  44.0         Single
# 2511         5/1/2021          153699    Male  48.0         Single
#
#          State_names   Segment Employees_status Payment_method  Referal  \
# 2         New Mexico     Basic          workers         PayPal      1.0
# ...

# %%
df.dtypes
# Out:
# Transaction_date     object
# Transaction_ID        int64
# Gender               object
# Age                 float64
# Marital_status       object
# State_names          object
# Segment              object
# Employees_status     object
# Payment_method       object
# Referal             float64
# Amount_spent        float64
# dtype: object
